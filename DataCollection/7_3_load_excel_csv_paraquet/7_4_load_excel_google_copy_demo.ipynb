# %% [markdown]
# how to load dataset from kaggle

# %%
# %pip install kagglehub

# %%
import os
os.environ["key"] = "value"

# %%
import kagglehub

# path = kagglehub.dataset_download("alessandrolobello/the-ultimate-earthquake-dataset-from-1990-2023")
path = kagglehub.dataset_download("uciml/pima-indians-diabetes-database")
print("Path to dataset files:", path)

# %%
import shutil

# copy the dataset from source to target directory

# shutil.copy("/kaggle/input/the-ultimate-earthquake-dataset-from-1990-2023",
#             "/content/dataset",
#             dirs_exist_ok=True)
shutil.copytree("/kaggle/input/pima-indians-diabetes-database",
            "/content/dataset",
            dirs_exist_ok=True)

# %%
import pandas as pd

# %%
# df = pd.read_csv("/content/dataset/Eartquakes-1990-2023.csv")
df = pd.read_csv("/content/dataset/diabetes.csv")
