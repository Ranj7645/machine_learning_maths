# %%
# %pip install SQLAlchemy psycopg2-binary
# Out:
# ...
#                                               0.0/2.1 MB ? eta -:--:--
#                                               0.0/2.1 MB 2.0 MB/s eta 0:00:02
#      -                                        0.1/2.1 MB 991.0 kB/s eta 0:00:03
#      ---------                                0.5/2.1 MB 4.7 MB/s eta 0:00:01
#      --------------                           0.8/2.1 MB 6.1 MB/s eta 0:00:01
#      ------------------                       1.0/2.1 MB 5.1 MB/s eta 0:00:01
#      --------------------                     1.1/2.1 MB 5.0 MB/s eta 0:00:01
#      --------------------                     1.1/2.1 MB 5.0 MB/s eta 0:00:01
#      --------------------                     1.1/2.1 MB 5.0 MB/s eta 0:00:01
#      ---------------------                    1.2/2.1 MB 3.4 MB/s eta 0:00:01
#      --------------------------               1.4/2.1 MB 3.6 MB/s eta 0:00:01
#      --------------------------               1.4/2.1 MB 3.6 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# connection string / url
connection_string = "postgresql://postgres:newpassword@localhost:5433/ml_db"
engine = create_engine(url=connection_string)

# %%
df = pd.read_sql(
    sql="select * from datasets.diabetes",
    con=engine
)

# %%
df.head()
# Out:
#    pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    diabetespedigreefunction  age  outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.to_csv("diabetes_copy.csv",index=False)
